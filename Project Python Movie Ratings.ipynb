# %%
#Import libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8)#Adjusts the configuration of the plots we will create

# %%
#Read in the data

df=pd.read_csv("P2-Movie-Ratings.csv")

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
#Check for missing values

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# Film - 0.0%
# Genre - 0.0%
# Rotten Tomatoes Ratings % - 0.0%
# Audience Ratings % - 0.0%
# Budget (million $) - 0.0%
# Year of release - 0.0%

# %%
#Data types for our columns

df.dtypes
# Out:
# Film                         object
# Genre                        object
# Rotten Tomatoes Ratings %     int64
# Audience Ratings %            int64
# Budget (million $)            int64
# Year of release               int64
# dtype: object

# %%
#Drop any duplicates

df.nunique()
# Out:
# Film                         562
# Genre                          7
# Rotten Tomatoes Ratings %     98
# Audience Ratings %            74
# Budget (million $)            99
# Year of release                5
# dtype: int64

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                            Film      Genre  Rotten Tomatoes Ratings %  \
# 0         (500) Days of Summer      Comedy                         87
# 1                   10,000 B.C.  Adventure                          9
# 2                    12 Rounds      Action                         30
# 3                     127 Hours  Adventure                         93
# 4                     17 Again      Comedy                         55
# ..                          ...        ...                        ...
# 557             Youth in Revolt     Comedy                         68
# 558  Zack and Miri Make a Porno    Romance                         64
# 559                      Zodiac   Thriller                         89
# 560                 Zombieland      Action                         90
# 561                   Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# ...

# %%
df.tail()
# Out:
#                            Film     Genre  Rotten Tomatoes Ratings %  \
# 557             Youth in Revolt    Comedy                         68
# 558  Zack and Miri Make a Porno   Romance                         64
# 559                      Zodiac  Thriller                         89
# 560                 Zombieland     Action                         90
# 561                   Zookeeper    Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 557                  52                  18             2009
# 558                  70                  24             2008
# 559                  73                  65             2007
# 560                  87                  24             2009
# 561                  42                  80             2011

# %%
#Budget high correlation
#Genre high correlation

# %%
plt.scatter(x=df["Budget (million $)"],y=df["Rotten Tomatoes Ratings %"])
plt.title('Budget vs Rotten Tomatoes Ratings %')

plt.xlabel('Budget')
plt.ylabel('Rotten Tomatoes Ratings %')
# Out:
# Text(0, 0.5, 'Rotten Tomatoes Ratings %')

# %%
plt.scatter(x=df["Budget (million $)"],y=df["Audience Ratings %"])

plt.title('Budget vs Audience Ratings')

plt.xlabel('Budget')
plt.ylabel('Audience Ratings')
# Out:
# Text(0, 0.5, 'Audience Ratings')

# %%
plt.scatter(x=df["Rotten Tomatoes Ratings %"],y=df["Audience Ratings %"])

plt.title('Rotten Tomatoes Ratings % vs Audience Ratings')

plt.xlabel('Rotten Tomatoes Ratings %')
plt.ylabel('Audience Ratings')
# Out:
# Text(0, 0.5, 'Audience Ratings')

# %%
#Plot budget vs Rotten Tomatoes Ratings% using seaborn

# %%
sns.regplot(x='Budget (million $)',y='Rotten Tomatoes Ratings %',data=df, scatter_kws={"color":"red"},line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Budget (million $)', ylabel='Rotten Tomatoes Ratings %'>

# %%
#Plot Audience Ratings % vs Rotten Tomatoes Ratings% using seaborn

# %%
sns.regplot(x='Audience Ratings %',y='Rotten Tomatoes Ratings %',data=df, scatter_kws={"color":"red"},line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='Audience Ratings %', ylabel='Rotten Tomatoes Ratings %'>

# %%
# Let´s start Looking at correlation

# %%
df.corr(method='pearson')# pearson, kendall, spearman
# Out:
#                            Rotten Tomatoes Ratings %  Audience Ratings %  \
# Rotten Tomatoes Ratings %                   1.000000            0.654655
# Audience Ratings %                          0.654655            1.000000
# Budget (million $)                          0.011755            0.188078
# Year of release                             0.047465           -0.065050
#
#                            Budget (million $)  Year of release
# Rotten Tomatoes Ratings %            0.011755         0.047465
# Audience Ratings %                   0.188078        -0.065050
# Budget (million $)                   1.000000        -0.017297
# Year of release                     -0.017297         1.000000

# %%
df.corr(method='kendall')
# Out:
#                            Rotten Tomatoes Ratings %  Audience Ratings %  \
# Rotten Tomatoes Ratings %                   1.000000            0.472713
# Audience Ratings %                          0.472713            1.000000
# Budget (million $)                         -0.051698            0.089476
# Year of release                             0.035237           -0.044335
#
#                            Budget (million $)  Year of release
# Rotten Tomatoes Ratings %           -0.051698         0.035237
# Audience Ratings %                   0.089476        -0.044335
# Budget (million $)                   1.000000         0.009410
# Year of release                      0.009410         1.000000

# %%
df.corr(method='spearman')
# Out:
#                            Rotten Tomatoes Ratings %  Audience Ratings %  \
# Rotten Tomatoes Ratings %                   1.000000            0.647772
# Audience Ratings %                          0.647772            1.000000
# Budget (million $)                         -0.076552            0.129218
# Year of release                             0.048502           -0.058687
#
#                            Budget (million $)  Year of release
# Rotten Tomatoes Ratings %           -0.076552         0.048502
# Audience Ratings %                   0.129218        -0.058687
# Budget (million $)                   1.000000         0.013219
# Year of release                      0.013219         1.000000

# %%
#Hight correlation between Audience Ratings and Rotten Tomatoes Rating

# %%
correlation_matrix=df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.show()

# %%
#Looks at Genre
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df_numerized=df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype=='object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#      Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0       0      2                         87                  81
# 1       1      1                          9                  44
# 2       2      0                         30                  52
# 3       3      1                         93                  84
# 4       4      2                         55                  70
# ..    ...    ...                        ...                 ...
# 557   557      2                         68                  52
# 558   558      5                         64                  70
# 559   559      6                         89                  73
# 560   560      0                         90                  87
# 561   561      2                         14                  42
#
#      Budget (million $)  Year of release
# 0                     8             2009
# 1                   105             2008
# 2                    20             2009
# ...

# %%
correlation_matrix2=df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix2, annot=True)

plt.show()

# %%
#There´s no correlation between Genre and Ratings nor between Budget and Ratings
